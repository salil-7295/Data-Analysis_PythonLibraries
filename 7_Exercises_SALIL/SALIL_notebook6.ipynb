# %% [markdown]
# # All about DataFrames Pandas objects

# %% [markdown]
# - Read the dataset 'fandango_score_comparison' in the fandango dataframe.
# - Return a dataframe containing only the first and last lines and assign the result to the first_last variable.
# - Display the result.

# %%
import pandas as pd

fandango = pd.read_csv("fandango_score_comparison.csv")
fandango.iloc[[0,-1]]
# Out:
#                                    FILM  RottenTomatoes  RottenTomatoes_User  \
# 0        Avengers: Age of Ultron (2015)              74                   86
# 145  Kumiko, The Treasure Hunter (2015)              87                   63
#
#      Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0            66              7.1   7.8             5.0                   4.5
# 145          68              6.4   6.7             3.5                   3.5
#
#      RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# 0       3.70          4.30  ...       3.90            3.5                 4.5
# 145     4.35          3.15  ...       3.35            4.5                 3.0
#
#      Metacritic_norm_round  Metacritic_user_norm_round  IMDB_norm_round  \
# 0                      3.5                         3.5              4.0
# 145                    3.5                         3.0              3.5
#
#      Metacritic_user_vote_count  IMDB_user_vote_count  Fandango_votes  \
# 0                          1330                271107           14846
# 145                          19                  5289              41
#
#      Fandango_Difference
# 0                    0.5
# 145                  0.0
#
# [2 rows x 22 columns]

# %% [markdown]
# ## Use custom indexes

# %% [markdown]
# - Use the set_index method to index our fandango DataFrame with the 'FILM' column. Note that we want to keep the 'FILM' column. Furthermore we want to keep the original DataFrame and create a new one that we will assign to the fandango_films variable.
# - Display the index of the DataFrame fandango_films in the iade of the index attribute.

# %%
fandango_films = fandango.set_index('FILM')
fandango_films.index
# Out:
# Index(['Avengers: Age of Ultron (2015)', 'Cinderella (2015)', 'Ant-Man (2015)',
#        'Do You Believe? (2015)', 'Hot Tub Time Machine 2 (2015)',
#        'The Water Diviner (2015)', 'Irrational Man (2015)', 'Top Five (2014)',
#        'Shaun the Sheep Movie (2015)', 'Love & Mercy (2015)',
#        ...
#        'The Woman In Black 2 Angel of Death (2015)', 'Danny Collins (2015)',
#        'Spare Parts (2015)', 'Serena (2015)', 'Inside Out (2015)',
#        'Mr. Holmes (2015)', ''71 (2015)', 'Two Days, One Night (2014)',
#        'Gett: The Trial of Viviane Amsalem (2015)',
#        'Kumiko, The Treasure Hunter (2015)'],
#       dtype='object', name='FILM', length=146)

# %% [markdown]
# ## Selecting values from an index

# %% [markdown]
# - Select the following movies from the DataFrame fandango_films (in the following order) and assign them to the some_movies variable:
# >- "Top Five (2014)"
# >- "Black Sea (2015)"
# >- "Taken 3 (2015)"
# - Display the result.

# %%
movies = ["Top Five (2014)", "Black Sea (2015)", "Taken 3 (2015)"]
some_movies = fandango_films.loc[movies]
some_movies
# Out:
#                   RottenTomatoes  RottenTomatoes_User  Metacritic  \
# FILM
# Top Five (2014)               86                   64          81
# Black Sea (2015)              82                   60          62
# Taken 3 (2015)                 9                   46          26
#
#                   Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# FILM
# Top Five (2014)               6.8   6.5             4.0                   3.5
# Black Sea (2015)              6.6   6.4             4.0                   3.5
# Taken 3 (2015)                4.6   6.1             4.5                   4.1
#
#                   RT_norm  RT_user_norm  Metacritic_norm  ...  IMDB_norm  \
# FILM                                                      ...
# Top Five (2014)      4.30           3.2             4.05  ...       3.25
# Black Sea (2015)     4.10           3.0             3.10  ...       3.20
# Taken 3 (2015)       0.45           2.3             1.30  ...       3.05
#
#                   RT_norm_round  RT_user_norm_round  Metacritic_norm_round  \
# FILM
# Top Five (2014)             4.5                 3.0                    4.0
# Black Sea (2015)            4.0                 3.0                    3.0
# Taken 3 (2015)              0.5                 2.5                    1.5
#
#                   Metacritic_user_norm_round  IMDB_norm_round  \
# FILM
# Top Five (2014)                          3.5              3.5
# Black Sea (2015)                         3.5              3.0
# Taken 3 (2015)                           2.5              3.0
#
#                   Metacritic_user_vote_count  IMDB_user_vote_count  \
# FILM
# Top Five (2014)                          124                 16876
# Black Sea (2015)                          37                 16547
# Taken 3 (2015)                           240                104235
#
#                   Fandango_votes  Fandango_Difference
# FILM
# Top Five (2014)             3223                  0.5
# Black Sea (2015)             218                  0.5
# Taken 3 (2015)              6757                  0.4
#
# [3 rows x 21 columns]

# %% [markdown]
# ## Apply() method on the columns of a DataFrame

# %% [markdown]
# - Get the float_df dataframe I made as an example (which returns the float64 decimal columns)
# - Use the apply() method on this float_df dataframe to halve each value and assign the result to the exo_df variable.
# - Display the first lines of the result.

# %%
float_df = fandango_films.astype(float)

# %%
exo_df = float_df.apply(lambda x: x / 2)

# %%
exo_df.head()
# Out:
#                                 RottenTomatoes  RottenTomatoes_User  \
# FILM
# Avengers: Age of Ultron (2015)            37.0                 43.0
# Cinderella (2015)                         42.5                 40.0
# Ant-Man (2015)                            40.0                 45.0
# Do You Believe? (2015)                     9.0                 42.0
# Hot Tub Time Machine 2 (2015)              7.0                 14.0
#
#                                 Metacritic  Metacritic_User  IMDB  \
# FILM
# Avengers: Age of Ultron (2015)        33.0             3.55  3.90
# Cinderella (2015)                     33.5             3.75  3.55
# Ant-Man (2015)                        32.0             4.05  3.90
# Do You Believe? (2015)                11.0             2.35  2.70
# Hot Tub Time Machine 2 (2015)         14.5             1.70  2.55
#
#                                 Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# FILM
# Avengers: Age of Ultron (2015)            2.50                  2.25    1.850
# Cinderella (2015)                         2.50                  2.25    2.125
# Ant-Man (2015)                            2.50                  2.25    2.000
# Do You Believe? (2015)                    2.50                  2.25    0.450
# Hot Tub Time Machine 2 (2015)             1.75                  1.50    0.350
#
#                                 RT_user_norm  Metacritic_norm  ...  IMDB_norm  \
# FILM                                                           ...
# Avengers: Age of Ultron (2015)          2.15            1.650  ...      1.950
# Cinderella (2015)                       2.00            1.675  ...      1.775
# Ant-Man (2015)                          2.25            1.600  ...      1.950
# Do You Believe? (2015)                  2.10            0.550  ...      1.350
# Hot Tub Time Machine 2 (2015)           0.70            0.725  ...      1.275
#
#                                 RT_norm_round  RT_user_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)           1.75                2.25
# Cinderella (2015)                        2.25                2.00
# Ant-Man (2015)                           2.00                2.25
# Do You Believe? (2015)                   0.50                2.00
# Hot Tub Time Machine 2 (2015)            0.25                0.75
#
#                                 Metacritic_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)                   1.75
# Cinderella (2015)                                1.75
# Ant-Man (2015)                                   1.50
# Do You Believe? (2015)                           0.50
# Hot Tub Time Machine 2 (2015)                    0.75
#
#                                 Metacritic_user_norm_round  IMDB_norm_round  \
# FILM
# Avengers: Age of Ultron (2015)                        1.75             2.00
# Cinderella (2015)                                     2.00             1.75
# Ant-Man (2015)                                        2.00             2.00
# Do You Believe? (2015)                                1.25             1.25
# Hot Tub Time Machine 2 (2015)                         0.75             1.25
#
#                                 Metacritic_user_vote_count  \
# FILM
# Avengers: Age of Ultron (2015)                       665.0
# Cinderella (2015)                                    124.5
# Ant-Man (2015)                                       313.5
# Do You Believe? (2015)                                15.5
# Hot Tub Time Machine 2 (2015)                         44.0
#
#                                 IMDB_user_vote_count  Fandango_votes  \
# FILM
# Avengers: Age of Ultron (2015)              135553.5          7423.0
# Cinderella (2015)                            32854.5          6320.0
# Ant-Man (2015)                               51830.0          6027.5
# Do You Believe? (2015)                        1568.0           896.5
# Hot Tub Time Machine 2 (2015)                 9780.0           510.5
#
#                                 Fandango_Difference
# FILM
# Avengers: Age of Ultron (2015)                 0.25
# Cinderella (2015)                              0.25
# Ant-Man (2015)                                 0.25
# Do You Believe? (2015)                         0.25
# Hot Tub Time Machine 2 (2015)                  0.25
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Apply() method on the lines of a DataFrame

# %% [markdown]
# - Use the apply() method to calculate the average (mean() method from the Numpy library) of the values of each movie for 'RT_user_norm' and 'metacritic_user_name' and then assign the result to the variable rt_mt_means.
# - Display the first 5 values of rt_mt_means.

# %%
import numpy as np
data = fandango[["RT_user_norm", "Metacritic_User"]]
rt_mt_mean = data.apply(lambda x : np.mean(x), axis=1)

rt_mt_mean.head(5)
# Out:
# 0    5.70
# 1    5.75
# 2    6.30
# 3    4.45
# 4    2.40
# dtype: float64
